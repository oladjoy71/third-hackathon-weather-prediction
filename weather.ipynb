# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
weather = pd.read_csv(r"weatherAUS.csv")

# %%
weather.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
weather.shape
# Out:
# (145460, 23)

# %%
weather.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
weather.describe(include="all")
# Out:
#               Date  Location        MinTemp        MaxTemp       Rainfall  \
# count       145460    145460  143975.000000  144199.000000  142199.000000
# unique        3436        49            NaN            NaN            NaN
# top     2013-11-12  Canberra            NaN            NaN            NaN
# freq            49      3436            NaN            NaN            NaN
# mean           NaN       NaN      12.194034      23.221348       2.360918
# std            NaN       NaN       6.398495       7.119049       8.478060
# min            NaN       NaN      -8.500000      -4.800000       0.000000
# 25%            NaN       NaN       7.600000      17.900000       0.000000
# 50%            NaN       NaN      12.000000      22.600000       0.000000
# 75%            NaN       NaN      16.900000      28.200000       0.800000
# max            NaN       NaN      33.900000      48.100000     371.000000
#
#          Evaporation      Sunshine WindGustDir  WindGustSpeed WindDir9am  ...  \
# ...

# %%
weather.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
weather["Location"].unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
weather["Evaporation"].unique()
# Out:
# array([     nan, 1.20e+01, 1.48e+01, 1.26e+01, 1.08e+01, 1.14e+01,
#        1.12e+01, 1.30e+01, 9.80e+00, 1.46e+01, 1.10e+01, 1.28e+01,
#        1.38e+01, 1.64e+01, 1.74e+01, 1.60e+01, 1.36e+01, 8.00e+00,
#        8.20e+00, 8.60e+00, 1.42e+01, 1.58e+01, 1.62e+01, 1.34e+01,
#        1.44e+01, 1.18e+01, 1.56e+01, 1.52e+01, 1.16e+01, 9.60e+00,
#        6.60e+00, 6.00e-01, 6.00e+00, 3.00e+00, 2.00e+00, 5.20e+00,
#        9.00e+00, 1.02e+01, 1.00e+01, 7.40e+00, 8.40e+00, 9.20e+00,
#        9.40e+00, 1.24e+01, 1.04e+01, 7.20e+00, 6.80e+00, 7.60e+00,
#        4.40e+00, 6.40e+00, 7.80e+00, 7.00e+00, 8.80e+00, 6.20e+00,
#        5.80e+00, 2.00e-01, 2.40e+00, 1.80e+00, 2.20e+00, 2.80e+00,
#        5.00e+00, 5.60e+00, 4.80e+00, 4.20e+00, 4.00e+00, 3.20e+00,
#        4.60e+00, 3.40e+00, 3.60e+00, 0.00e+00, 1.40e+00, 3.80e+00,
#        8.00e-01, 2.60e+00, 1.60e+00, 1.20e+00, 1.00e+00, 5.40e+00,
#        1.06e+01, 1.68e+01, 1.70e+01, 2.02e+01, 1.40e+01, 1.72e+01,
# ...

# %%
weather = weather.drop(["Date"],axis=1 )

# %%
weather.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6          NaN       NaN           W
# 1   Albury      7.4     25.1       0.0          NaN       NaN         WNW
# 2   Albury     12.9     25.7       0.0          NaN       NaN         WSW
# 3   Albury      9.2     28.0       0.0          NaN       NaN          NE
# 4   Albury     17.5     32.3       1.0          NaN       NaN           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0           44.0          W        WNW  ...         71.0         22.0
# 1           44.0        NNW        WSW  ...         44.0         25.0
# 2           46.0          W        WSW  ...         38.0         30.0
# 3           24.0         SE          E  ...         45.0         16.0
# 4           41.0        ENE         NW  ...         82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
weather["MaxTemp"].unique()
# Out:
# array([22.9, 25.1, 25.7, 28. , 32.3, 29.7, 25. , 26.7, 31.9, 30.1, 30.4,
#        21.7, 18.6, 21. , 24.6, 27.7, 20.9, 22.5, 25.6, 29.3, 33. , 31.8,
#        30.9, 32.4, 33.9, 32.7, 27.2, 24.2, 24.4, 26.5, 23.9, 28.8, 34.6,
#        35.8, 37.9, 38.9, 28.3, 28.4, 30.8, 32. , 34.7, 37.7, 43. , 32.2,
#        36.6, 39.9, 38.1, 34. , 35.2, 30.6, 34.3, 38.4, 38.2, 40.7, 41.5,
#        42.9, 42.7, 43.1, 38.3, 36.9, 41.2, 42.2, 44.8, 40.2, 31.2, 27.3,
#        21.6, 29. , 29.2, 31.3, 31.1, 29.1, 31.7, 33.2, 29.6, 32.6, 34.5,
#        30.3, 22.1, 22. , 24. , 27.9, 30.2, 30.5, 25.8, 27. , 19.7, 21.9,
#        25.3, 33.5, 33.6, 30. , 31.6, 22.3, 29.8, 27.6, 28.9, 29.9, 32.1,
#        28.1, 21.4, 24.9, 25.4, 20. , 23.4, 22.7, 16.2, 15.8, 12.9, 11.5,
#        14.5, 12.2, 16.5, 17. , 19.2, 18.9, 19.1, 18.8, 19.3, 18.4, 19. ,
#        20.5, 19.5, 17.7, 18.5, 15.1, 16.3, 16.6, 16.4, 15.6, 19.8, 21.1,
#        20.3, 18.1, 15.7, 16.8, 17.1, 14.3, 13.4, 17.4, 16.1, 10.5, 11.6,
# ...

# %%
weather["RainTomorrow"].fillna(method = "ffill", inplace=True)

# %%
weather["RainTomorrow"].isnull().sum()
# Out:
# 0

# %%
weather[["RainTomorrow"]]
# Out:
#        RainTomorrow
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# ...             ...
# 145455           No
# 145456           No
# 145457           No
# 145458           No
# 145459           No
#
# [145460 rows x 1 columns]

# %%
weather.isnull().sum()
# Out:
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow         0
# dtype: int64

# %%
weather.describe(include = "all")
# Out:
#         Location        MinTemp        MaxTemp       Rainfall   Evaporation  \
# count     145460  143975.000000  144199.000000  142199.000000  82670.000000
# unique        49            NaN            NaN            NaN           NaN
# top     Canberra            NaN            NaN            NaN           NaN
# freq        3436            NaN            NaN            NaN           NaN
# mean         NaN      12.194034      23.221348       2.360918      5.468232
# std          NaN       6.398495       7.119049       8.478060      4.193704
# min          NaN      -8.500000      -4.800000       0.000000      0.000000
# 25%          NaN       7.600000      17.900000       0.000000      2.600000
# 50%          NaN      12.000000      22.600000       0.000000      4.800000
# 75%          NaN      16.900000      28.200000       0.800000      7.400000
# max          NaN      33.900000      48.100000     371.000000    145.000000
#
# ...

# %%
weather.isnull().sum()
# Out:
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow         0
# dtype: int64

# %%
weather["Humidity9am"].unique()
# Out:
# array([ 71.,  44.,  38.,  45.,  82.,  55.,  49.,  48.,  42.,  58.,  89.,
#         76.,  65.,  57.,  50.,  69.,  80.,  47.,  56.,  54.,  41.,  78.,
#         46.,  43.,  33.,  34.,  36.,  52.,  51.,  40.,  35.,  39.,  60.,
#         37.,  27.,  32.,  53.,  20.,  66.,  63.,  62.,  87.,  61.,  59.,
#         92.,  72.,  67.,  75.,  88.,  68.,  73.,  74.,  83.,  77.,  70.,
#         81.,  86.,  97.,  99.,  91.,  85.,  93.,  84.,  94.,  79.,  98.,
#         96.,  95.,  90.,  64.,  29.,  21., 100.,  nan,  24.,  25.,  31.,
#         18.,  23.,  26.,  28.,  30.,  19.,  22.,  17.,  15.,   9.,  12.,
#         13.,  16.,   6.,  10.,  14.,  11.,   7.,   8.,   5.,   3.,   2.,
#          4.,   0.,   1.])

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 22 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       145460 non-null  object
#  1   MinTemp        143975 non-null  float64
#  2   MaxTemp        144199 non-null  float64
#  3   Rainfall       142199 non-null  float64
#  4   Evaporation    82670 non-null   float64
#  5   Sunshine       75625 non-null   float64
#  6   WindGustDir    135134 non-null  object
#  7   WindGustSpeed  135197 non-null  float64
#  8   WindDir9am     134894 non-null  object
#  9   WindDir3pm     141232 non-null  object
#  10  WindSpeed9am   143693 non-null  float64
#  11  WindSpeed3pm   142398 non-null  float64
#  12  Humidity9am    142806 non-null  float64
#  13  Humidity3pm    140953 non-null  float64
#  14  Pressure9am    130395 non-null  float64
#  15  Pressure3pm    130432 non-null  float64
# ...

# %%
number = weather.select_dtypes("number")

# %%
number.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0     13.4     22.9       0.6          NaN       NaN           44.0
# 1      7.4     25.1       0.0          NaN       NaN           44.0
# 2     12.9     25.7       0.0          NaN       NaN           46.0
# 3      9.2     28.0       0.0          NaN       NaN           24.0
# 4     17.5     32.3       1.0          NaN       NaN           41.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0          20.0          24.0         71.0         22.0       1007.7
# 1           4.0          22.0         44.0         25.0       1010.6
# 2          19.0          26.0         38.0         30.0       1007.6
# 3          11.0           9.0         45.0         16.0       1017.6
# 4           7.0          20.0         82.0         33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm
# 0       1007.1       8.0       NaN     16.9     21.8
# ...

# %%
number.fillna(number.median(), axis= 0, inplace=True)
# Out:
# C:\Users\OLADJOY\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
number.isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# dtype: int64

# %%
number["Humidity9am"].unique()
# Out:
# array([ 71.,  44.,  38.,  45.,  82.,  55.,  49.,  48.,  42.,  58.,  89.,
#         76.,  65.,  57.,  50.,  69.,  80.,  47.,  56.,  54.,  41.,  78.,
#         46.,  43.,  33.,  34.,  36.,  52.,  51.,  40.,  35.,  39.,  60.,
#         37.,  27.,  32.,  53.,  20.,  66.,  63.,  62.,  87.,  61.,  59.,
#         92.,  72.,  67.,  75.,  88.,  68.,  73.,  74.,  83.,  77.,  70.,
#         81.,  86.,  97.,  99.,  91.,  85.,  93.,  84.,  94.,  79.,  98.,
#         96.,  95.,  90.,  64.,  29.,  21., 100.,  24.,  25.,  31.,  18.,
#         23.,  26.,  28.,  30.,  19.,  22.,  17.,  15.,   9.,  12.,  13.,
#         16.,   6.,  10.,  14.,  11.,   7.,   8.,   5.,   3.,   2.,   4.,
#          0.,   1.])

# %%
cat = weather.select_dtypes("object")

# %%
cat.head()
# Out:
#   Location WindGustDir WindDir9am WindDir3pm RainToday RainTomorrow
# 0   Albury           W          W        WNW        No           No
# 1   Albury         WNW        NNW        WSW        No           No
# 2   Albury         WSW          W        WSW        No           No
# 3   Albury          NE         SE          E        No           No
# 4   Albury           W        ENE         NW        No           No

# %%
cat.isnull().sum()
# Out:
# Location            0
# WindGustDir     10326
# WindDir9am      10566
# WindDir3pm       4228
# RainToday        3261
# RainTomorrow        0
# dtype: int64

# %%
cat.fillna(method="ffill", axis = 0, inplace=True)
# Out:
# C:\Users\OLADJOY\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:5182: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
cat.isnull().sum()
# Out:
# Location        0
# WindGustDir     0
# WindDir9am      0
# WindDir3pm      0
# RainToday       0
# RainTomorrow    0
# dtype: int64

# %%
weather = pd.concat([number, cat], sort=False, axis=1)

# %%
weather.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0     13.4     22.9       0.6          4.8       8.4           44.0
# 1      7.4     25.1       0.0          4.8       8.4           44.0
# 2     12.9     25.7       0.0          4.8       8.4           46.0
# 3      9.2     28.0       0.0          4.8       8.4           24.0
# 4     17.5     32.3       1.0          4.8       8.4           41.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  Cloud9am  \
# 0          20.0          24.0         71.0         22.0  ...       8.0
# 1           4.0          22.0         44.0         25.0  ...       5.0
# 2          19.0          26.0         38.0         30.0  ...       5.0
# 3          11.0           9.0         45.0         16.0  ...       5.0
# 4           7.0          20.0         82.0         33.0  ...       7.0
#
#    Cloud3pm  Temp9am  Temp3pm  Location  WindGustDir WindDir9am WindDir3pm  \
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, OneHotEncoder

# %%
ordinal = OrdinalEncoder()

# %%
weather = ordinal.fit_transform(weather)

# %%
weather = pd.DataFrame(weather, columns=[ 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
       'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
       'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
       'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
       'Temp3pm', 'RainToday', 'RainTomorrow'])

# %%
weather.head()
# Out:
#    Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0     213.0    262.0      6.0      48.0         84.0      21.0         11.0
# 1     153.0    284.0      0.0      48.0         84.0      21.0          2.0
# 2     208.0    290.0      0.0      48.0         84.0      22.0         10.0
# 3     171.0    313.0      0.0      48.0         84.0      10.0          6.0
# 4     254.0    356.0     10.0      48.0         84.0      19.0          4.0
#
#    WindGustSpeed  WindDir9am  WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0           13.0        71.0        22.0  ...          8.0          5.0
# 1           12.0        44.0        25.0  ...          5.0          5.0
# 2           14.0        38.0        30.0  ...          5.0          2.0
# 3            5.0        45.0        16.0  ...          5.0          5.0
# 4           11.0        82.0        33.0  ...          7.0          8.0
#
# ...

# %%
weather.drop(["RainToday"], axis=1, inplace=True)

# %%
weather.isnull().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainTomorrow     0
# dtype: int64

# %%
weather.dtypes
# Out:
# Location         float64
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir      float64
# WindGustSpeed    float64
# WindDir9am       float64
# WindDir3pm       float64
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainTomorrow     float64
# dtype: object

# %%
X = weather.drop(["RainTomorrow"], axis=1)
y = weather["RainTomorrow"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=123)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_jobs=1, n_estimators=100, criterion ='gini')

# %%
#model = rf.fit(X_train, y_train)

# %%
#predict = model.predict(X_test)

# %%
#predict

# %%
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix

# %%
#f1_score(y_test, predict)

# %%
#accuracy_score(y_test, predict)

# %%
#from sklearn.tree import DecisionTreeClassifier

# %%
#dc = DecisionTreeClassifier()

# %%
#model1 = dc.fit(X_train, y_train)

# %%
#pred = model1.predict(X_test)

# %%
#pred

# %%
#f1_score(y_test,pred)

# %%
sns.countplot(weather.RainTomorrow)

# %%
from catboost import CatBoostClassifier

# %%
cat = CatBoostClassifier()

# %%
#mod = cat.fit(X_train, y_train)

# %%
#pred = mod.predict(X_test)

# %%
#pred

# %%
#f1_score(y_test,pred)

# %%
weather.RainTomorrow.value_counts()
# Out:
# 0.0    112701
# 1.0     32759
# Name: RainTomorrow, dtype: int64

# %%
count_0, count_1 = weather.RainTomorrow.value_counts()

# %%
count_0
# Out:
# 112701

# %%
data_0 = weather[weather.RainTomorrow == 0.0]

# %%
data_0
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0          213.0    262.0      6.0      48.0         84.0      21.0
# 1          153.0    284.0      0.0      48.0         84.0      21.0
# 2          208.0    290.0      0.0      48.0         84.0      22.0
# 3          171.0    313.0      0.0      48.0         84.0      10.0
# 4          254.0    356.0     10.0      48.0         84.0      19.0
# ...          ...      ...      ...       ...          ...       ...
# 145455     107.0    267.0      0.0      48.0         84.0      14.0
# 145456     115.0    286.0      0.0      48.0         84.0       9.0
# 145457     133.0    302.0      0.0      48.0         84.0      17.0
# 145458     157.0    303.0      0.0      48.0         84.0      12.0
# 145459     228.0    259.0      0.0      48.0         84.0      18.0
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  WindSpeed3pm  \
# ...

# %%
data_1 = weather[weather.RainTomorrow == 1.0]

# %%
data_1
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 8          176.0    352.0      0.0      48.0         84.0      40.0
# 10         213.0    337.0      0.0      48.0         84.0      13.0
# 11         238.0    250.0     22.0      48.0         84.0      14.0
# 12         238.0    219.0    137.0      48.0         84.0      30.0
# 16         220.0    242.0      0.0      48.0         84.0       9.0
# ...          ...      ...      ...       ...          ...       ...
# 145324     327.0    431.0      4.0      48.0         84.0      32.0
# 145390     272.0    277.0      0.0      48.0         84.0      16.0
# 145391     231.0    248.0     65.0      48.0         84.0      13.0
# 145392     256.0    302.0    116.0      48.0         84.0      16.0
# 145393     265.0    319.0    258.0      48.0         84.0      22.0
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  WindSpeed3pm  \
# ...

# %%
data_1_sample = data_1.sample(n= 112701, replace=True )

# %%
data_1_sample
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 131152     210.0    199.0     16.0      60.0         10.0      28.0
# 175        172.0    236.0      0.0      48.0         84.0      14.0
# 21319      192.0    214.0     10.0      38.0         98.0      13.0
# 15216      223.0    246.0     92.0      48.0         84.0      18.0
# 1996       145.0    149.0      0.0      48.0         84.0       9.0
# ...          ...      ...      ...       ...          ...       ...
# 84595      292.0    325.0      2.0      68.0         83.0      23.0
# 48408      173.0    328.0      0.0      48.0         84.0      25.0
# 47814      199.0    279.0      0.0      48.0         84.0      15.0
# 121437     170.0    207.0    110.0      30.0         67.0      22.0
# 17620      272.0    320.0     30.0      48.0         84.0      18.0
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  WindSpeed3pm  \
# ...

# %%
new_weather = pd.concat([data_0, data_1_sample], axis=0)

# %%
new_weather
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0          213.0    262.0      6.0      48.0         84.0      21.0
# 1          153.0    284.0      0.0      48.0         84.0      21.0
# 2          208.0    290.0      0.0      48.0         84.0      22.0
# 3          171.0    313.0      0.0      48.0         84.0      10.0
# 4          254.0    356.0     10.0      48.0         84.0      19.0
# ...          ...      ...      ...       ...          ...       ...
# 84595      292.0    325.0      2.0      68.0         83.0      23.0
# 48408      173.0    328.0      0.0      48.0         84.0      25.0
# 47814      199.0    279.0      0.0      48.0         84.0      15.0
# 121437     170.0    207.0    110.0      30.0         67.0      22.0
# 17620      272.0    320.0     30.0      48.0         84.0      18.0
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  WindSpeed3pm  \
# ...

# %%
new_weather.RainTomorrow.value_counts()
# Out:
# 0.0    112701
# 1.0    112701
# Name: RainTomorrow, dtype: int64

# %%
X = new_weather.drop(["RainTomorrow"], axis=1)
y = new_weather["RainTomorrow"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=123)

# %%
mod = cat.fit(X_train, y_train)
# Out:
# Learning rate set to 0.089434
# 0:	learn: 0.6555780	total: 87.3ms	remaining: 1m 27s
# 1:	learn: 0.6259167	total: 140ms	remaining: 1m 9s
# 2:	learn: 0.6014069	total: 204ms	remaining: 1m 7s
# 3:	learn: 0.5819373	total: 259ms	remaining: 1m 4s
# 4:	learn: 0.5645341	total: 330ms	remaining: 1m 5s
# 5:	learn: 0.5507699	total: 388ms	remaining: 1m 4s
# 6:	learn: 0.5395486	total: 450ms	remaining: 1m 3s
# 7:	learn: 0.5298039	total: 504ms	remaining: 1m 2s
# 8:	learn: 0.5208620	total: 556ms	remaining: 1m 1s
# 9:	learn: 0.5133261	total: 615ms	remaining: 1m
# 10:	learn: 0.5073202	total: 684ms	remaining: 1m 1s
# 11:	learn: 0.5019379	total: 745ms	remaining: 1m 1s
# 12:	learn: 0.4974450	total: 811ms	remaining: 1m 1s
# 13:	learn: 0.4932042	total: 918ms	remaining: 1m 4s
# 14:	learn: 0.4898554	total: 984ms	remaining: 1m 4s
# 15:	learn: 0.4863568	total: 1.04s	remaining: 1m 3s
# 16:	learn: 0.4834806	total: 1.1s	remaining: 1m 3s
# 17:	learn: 0.4812581	total: 1.17s	remaining: 1m 3s
# ...

# %%
#predict_mod = mod.predict(X_test)

# %%
#predict_mod

# %%
#f1_score(predict_mod, y_test)

# %% [markdown]
# # Randomforest

# %%
rf = rf.fit(X_train, y_train)

# %%
mod = rf.predict(X_test)

# %%
mod
# Out:
# array([0., 1., 0., ..., 1., 0., 1.])

# %%
print (" the f1score for the test set:", f1_score(mod, y_test))
# Out:
#  the f1score for the test set: 0.9401692183722804

# %%
mod2 = rf.predict(X_train)

# %%
print (" f1score for train set:",f1_score(mod2, y_train))
# Out:
#  f1score for train set: 0.9998606536610084

# %%
print ("accuracy socre for test set",accuracy_score(mod, y_test))
# Out:
# accuracy socre for test set 0.9385102261131897

# %%
print ("accuracy score for train set",accuracy_score(mod2,y_train))
# Out:
# accuracy score for train set 0.9998605662278728

# %%
from sklearn import metrics

# %%
metrics.confusion_matrix(mod, y_test)
# Out:
# array([[30794,  1095],
#        [ 3063, 32669]], dtype=int64)

# %%
sns.heatmap(metrics.confusion_matrix(mod, y_test))
